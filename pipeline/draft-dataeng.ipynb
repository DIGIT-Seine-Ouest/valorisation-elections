# %%
import json
import pandas as pd

# %% [markdown]
# ## 1 - Reconstruction des données EIREL

# %%
# Chargement des données avec les bonnes colonnes
def load_eirel(filepath, config_path='data/bronze/reference/eirel_columns.json'):
    with open(config_path, 'r') as f:
        config = json.load(f)
    
    colonnes = {int(k): v for k, v in config['fixed_columns'].items()}
    
    temp = pd.read_csv(filepath, sep=";", skiprows=2, header=None, usecols=[17], nrows=1)
    nb_listes = temp.iloc[0, 0]
    
    start_idx = config['dynamic_columns']['start_index']
    for i in range(1, nb_listes + 1):
        colonnes[start_idx + 2*(i-1)] = f"code_liste_{i}"
        colonnes[start_idx + 2*(i-1) + 1] = f"voix_liste_{i}"
    
    data = pd.read_csv(filepath, sep=";", skiprows=2, header=None)
    data.rename(columns=colonnes, inplace=True)
    
    return data

# %%
# Récupération des données EIREL avec les configurations précices
data = load_eirel("data/bronze/eirel/TEST_EIREL_MEUDON_28052024.txt")
data.head()
# Out:
#    num_ligne type_election  annee  tour  departement  commune  bureau_vote  \
# 0          1            ER   2024     1           92       48            1
# 1          2            ER   2024     1           92       48            2
# 2          3            ER   2024     1           92       48            3
# 3          4            ER   2024     1           92       48            4
# 4          5            ER   2024     1           92       48            5
#
#    circonscription  canton indicateur  ...  code_liste_34  voix_liste_34  \
# 0               17       8          I  ...              8              1
# 1               17       8          I  ...              8              1
# 2               17       8          I  ...              8             16
# 3               17       8          I  ...              8              0
# 4               17       8          I  ...              8              6
#
#    code_liste_35  voix_liste_35  code_liste_36  voix_liste_36  code_liste_37  \
# 0             32              1             44             10             36
# 1             32             20             44              1             36
# 2             32             12             44             12             36
# 3             32              0             44              0             36
# 4             32             15             44              3             36
#
#    voix_liste_37  code_liste_38  voix_liste_38
# 0              1             46              2
# 1              2             46              1
# 2              1             46              1
# 3              0             46              0
# 4             15             46             23
#
# [5 rows x 94 columns]

# %%
# Aperçu des colonnes
data.columns
# Out:
# Index(['num_ligne', 'type_election', 'annee', 'tour', 'departement', 'commune',
#        'bureau_vote', 'circonscription', 'canton', 'indicateur', 'nb_inscrits',
#        'nb_abstentions', 'nb_votants', 'nb_emargements', 'nb_blanc', 'nb_nuls',
#        'nb_exprimes', 'nb_listes', 'code_liste_1', 'voix_liste_1',
#        'code_liste_2', 'voix_liste_2', 'code_liste_3', 'voix_liste_3',
#        'code_liste_4', 'voix_liste_4', 'code_liste_5', 'voix_liste_5',
#        'code_liste_6', 'voix_liste_6', 'code_liste_7', 'voix_liste_7',
#        'code_liste_8', 'voix_liste_8', 'code_liste_9', 'voix_liste_9',
#        'code_liste_10', 'voix_liste_10', 'code_liste_11', 'voix_liste_11',
#        'code_liste_12', 'voix_liste_12', 'code_liste_13', 'voix_liste_13',
#        'code_liste_14', 'voix_liste_14', 'code_liste_15', 'voix_liste_15',
#        'code_liste_16', 'voix_liste_16', 'code_liste_17', 'voix_liste_17',
#        'code_liste_18', 'voix_liste_18', 'code_liste_19', 'voix_liste_19',
#        'code_liste_20', 'voix_liste_20', 'code_liste_21', 'voix_liste_21',
#        'code_liste_22', 'voix_liste_22', 'code_liste_23', 'voix_liste_23',
#        'code_liste_24', 'voix_liste_24', 'code_liste_25', 'voix_liste_25',
#        'code_liste_26', 'voix_liste_26', 'code_liste_27', 'voix_liste_27',
#        'code_liste_28', 'voix_liste_28', 'code_liste_29', 'voix_liste_29',
#        'code_liste_30', 'voix_liste_30', 'code_liste_31', 'voix_liste_31',
#        'code_liste_32', 'voix_liste_32', 'code_liste_33', 'voix_liste_33',
#        'code_liste_34', 'voix_liste_34', 'code_liste_35', 'voix_liste_35',
#        'code_liste_36', 'voix_liste_36', 'code_liste_37', 'voix_liste_37',
#        'code_liste_38', 'voix_liste_38'],
#       dtype='str')

# %%
# Dimension du jeu de données
data.shape
# Out:
# (32, 94)

# %% [markdown]
# Réflexion sur le modèle de données :
# - NUMERO_BUREAU --> Dispo "bureau_vote"
# - CODE_LIEU_DE_VOTE --> Dispo "bureau_vote"
# - NOM_BUREAU --> Jointure "bureau_vote"
# - circos --> canton
# - nb_Inscrits --> nb_inscrits
# - nb_Emargements --> emargements
# - nb_Votants --> votants
# - nb_Blanc --> nb_blanc
# - nb_Nuls --> nb_nuls
# - nb_Exprimes --> ???
# - nb_Procurations --> ???
# - Candidat --> Pivot table
# - nb_voix --> Pivot table
#
#
# Intéressant à récupérer pour interoperabilité et plus :
# - type_election
# - annee
# - tour
# - commune
# - abstentions

# %% [markdown]
# ## 2 - Sélection des colonnes à intégrer pour constituer le jeu de données

# %%
with open("data/bronze/reference/columns_repartition.json") as config_cols:
    cols_used = json.load(config_cols)

# %%
data[cols_used["metrics_bdv"]].head()
# Out:
#    bureau_vote type_election  annee  tour  commune  canton  nb_inscrits  \
# 0            1            ER   2024     1       48       8          939
# 1            2            ER   2024     1       48       8         1007
# 2            3            ER   2024     1       48       8         1023
# 3            4            ER   2024     1       48       8         1066
# 4            5            ER   2024     1       48       8         1020
#
#    nb_abstentions  nb_votants  nb_emargements  nb_blanc  nb_nuls
# 0             339         600             600        20       10
# 1             507         500             500         2        2
# 2             223         800             800         5        2
# 3             266         800             800         0        0
# 4             270         750             750         2        2

# %%
data[cols_used["candidats_voix"]].head()
# Out:
#    bureau_vote  code_liste_1  voix_liste_1  code_liste_2  voix_liste_2  \
# 0            1            38            10            40            20
# 1            2            38             2            40             2
# 2            3            38            50            40            20
# 3            4            38            10            40            10
# 4            5            38             6            40             2
#
#    code_liste_3  voix_liste_3  code_liste_4  voix_liste_4  code_liste_5  ...  \
# 0            28            10            25             5             5  ...
# 1            28             3            25             5             5  ...
# 2            28            20            25            70             5  ...
# 3            28            20            25           130             5  ...
# 4            28            10            25            58             5  ...
#
#    code_liste_34  voix_liste_34  code_liste_35  voix_liste_35  code_liste_36  \
# 0              8              1             32              1             44
# 1              8              1             32             20             44
# 2              8             16             32             12             44
# 3              8              0             32              0             44
# 4              8              6             32             15             44
#
#    voix_liste_36  code_liste_37  voix_liste_37  code_liste_38  voix_liste_38
# 0             10             36              1             46              2
# 1              1             36              2             46              1
# 2             12             36              1             46              1
# 3              0             36              0             46              0
# 4              3             36             15             46             23
#
# [5 rows x 77 columns]

# %% [markdown]
# ## 3 - Transformation de données
# > Faire une jointure pour récupérer les noms de bureaux de vote

# %% [markdown]
# ### 3.1 - Récupération des noms de bureau

# %%
# Données d'enrichissement --> 
bdv = pd.read_csv(
    "https://data.meudon.fr/api/explore/v2.1/catalog/datasets/bureaux-de-vote-electoraux-2026/exports/csv", 
    sep=";",
    usecols=["num_bureau", "nom_bureau"]
)
bdv.head()
# Out:
#    num_bureau                            nom_bureau
# 0          19             Ecole maternelle La Ruche
# 1          17              Ecole maternelle Prévert
# 2          32                         L'Avant-Seine
# 3          16  Ecole maternelle Jean de la Fontaine
# 4          20                 Pôle intergénérations

# %%
nom_bureau = data.merge(
    bdv, 
    left_on="bureau_vote", 
    right_on="num_bureau", 
    how="left"
)
nom_bureau = nom_bureau[["bureau_vote", "nom_bureau"]].copy()
nom_bureau.head()
# Out:
#    bureau_vote                     nom_bureau
# 0            1                         Mairie
# 1            2         Club Séniors Lavoisier
# 2            3     Espace jeunesse Val Fleury
# 3            4    Complexe sportif René Leduc
# 4            5  Ecole élémentaire Jules Ferry

# %% [markdown]
# ### 3.2 - Transformation pivot table pour récupération des candidats et nombres de voix

# %%
candidats_voix = data[cols_used["candidats_voix"]].head()
candidats_voix.head()
# Out:
#    bureau_vote  code_liste_1  voix_liste_1  code_liste_2  voix_liste_2  \
# 0            1            38            10            40            20
# 1            2            38             2            40             2
# 2            3            38            50            40            20
# 3            4            38            10            40            10
# 4            5            38             6            40             2
#
#    code_liste_3  voix_liste_3  code_liste_4  voix_liste_4  code_liste_5  ...  \
# 0            28            10            25             5             5  ...
# 1            28             3            25             5             5  ...
# 2            28            20            25            70             5  ...
# 3            28            20            25           130             5  ...
# 4            28            10            25            58             5  ...
#
#    code_liste_34  voix_liste_34  code_liste_35  voix_liste_35  code_liste_36  \
# 0              8              1             32              1             44
# 1              8              1             32             20             44
# 2              8             16             32             12             44
# 3              8              0             32              0             44
# 4              8              6             32             15             44
#
#    voix_liste_36  code_liste_37  voix_liste_37  code_liste_38  voix_liste_38
# 0             10             36              1             46              2
# 1              1             36              2             46              1
# 2             12             36              1             46              1
# 3              0             36              0             46              0
# 4              3             36             15             46             23
#
# [5 rows x 77 columns]

# %%
# Sélectionner uniquement les colonnes voix_liste_*
voix_cols = [col for col in candidats_voix.columns if col.startswith('voix_liste_')]

candidats_voix_long = candidats_voix.melt(
    id_vars='bureau_vote',
    value_vars=voix_cols,
    var_name='candidat',
    value_name='nb_voix'
)

# Extraire le numéro du candidat
# candidats_voix_long['candidat'] = candidats_voix_long['candidat'].str.extract(r'(\d+)').astype(int)
candidats_voix_long['candidat'] = candidats_voix_long['candidat']

candidats_voix_long.head()
# Out:
#    bureau_vote      candidat  nb_voix
# 0            1  voix_liste_1       10
# 1            2  voix_liste_1        2
# 2            3  voix_liste_1       50
# 3            4  voix_liste_1       10
# 4            5  voix_liste_1        6

# %%
candidats_voix_long.shape
# Out:
# (190, 3)

# %%
# Vérification du nombre de candidats
candidats_voix_long.candidat.nunique()
# Out:
# 38

# %% [markdown]
# ### 3.3 - Jointure finale

# %%
data[cols_used["metrics_bdv"]].head()
# Out:
#    bureau_vote type_election  annee  tour  commune  canton  nb_inscrits  \
# 0            1            ER   2024     1       48       8          939
# 1            2            ER   2024     1       48       8         1007
# 2            3            ER   2024     1       48       8         1023
# 3            4            ER   2024     1       48       8         1066
# 4            5            ER   2024     1       48       8         1020
#
#    nb_abstentions  nb_votants  nb_emargements  nb_blanc  nb_nuls
# 0             339         600             600        20       10
# 1             507         500             500         2        2
# 2             223         800             800         5        2
# 3             266         800             800         0        0
# 4             270         750             750         2        2

# %%
data_kpi = data[cols_used["metrics_bdv"]].copy()

# %%
data_gold = data_kpi.merge(
    candidats_voix_long, 
    left_on="bureau_vote", 
    right_on="bureau_vote", 
    how="inner"
)

# %%
data_gold.head()
# Out:
#    bureau_vote type_election  annee  tour  commune  canton  nb_inscrits  \
# 0            1            ER   2024     1       48       8          939
# 1            1            ER   2024     1       48       8          939
# 2            1            ER   2024     1       48       8          939
# 3            1            ER   2024     1       48       8          939
# 4            1            ER   2024     1       48       8          939
#
#    nb_abstentions  nb_votants  nb_emargements  nb_blanc  nb_nuls  \
# 0             339         600             600        20       10
# 1             339         600             600        20       10
# 2             339         600             600        20       10
# 3             339         600             600        20       10
# 4             339         600             600        20       10
#
#        candidat  nb_voix
# 0  voix_liste_1       10
# 1  voix_liste_2       20
# 2  voix_liste_3       10
# 3  voix_liste_4        5
# 4  voix_liste_5        2

# %%
data_gold[data_gold["bureau_vote"] == 2]
# Out:
#     bureau_vote type_election  annee  tour  commune  canton  nb_inscrits  \
# 38            2            ER   2024     1       48       8         1007
# 39            2            ER   2024     1       48       8         1007
# 40            2            ER   2024     1       48       8         1007
# 41            2            ER   2024     1       48       8         1007
# 42            2            ER   2024     1       48       8         1007
# 43            2            ER   2024     1       48       8         1007
# 44            2            ER   2024     1       48       8         1007
# 45            2            ER   2024     1       48       8         1007
# 46            2            ER   2024     1       48       8         1007
# 47            2            ER   2024     1       48       8         1007
# 48            2            ER   2024     1       48       8         1007
# 49            2            ER   2024     1       48       8         1007
# 50            2            ER   2024     1       48       8         1007
# 51            2            ER   2024     1       48       8         1007
# 52            2            ER   2024     1       48       8         1007
# 53            2            ER   2024     1       48       8         1007
# 54            2            ER   2024     1       48       8         1007
# 55            2            ER   2024     1       48       8         1007
# 56            2            ER   2024     1       48       8         1007
# 57            2            ER   2024     1       48       8         1007
# 58            2            ER   2024     1       48       8         1007
# 59            2            ER   2024     1       48       8         1007
# 60            2            ER   2024     1       48       8         1007
# 61            2            ER   2024     1       48       8         1007
# 62            2            ER   2024     1       48       8         1007
# 63            2            ER   2024     1       48       8         1007
# 64            2            ER   2024     1       48       8         1007
# 65            2            ER   2024     1       48       8         1007
# 66            2            ER   2024     1       48       8         1007
# 67            2            ER   2024     1       48       8         1007
# 68            2            ER   2024     1       48       8         1007
# 69            2            ER   2024     1       48       8         1007
# 70            2            ER   2024     1       48       8         1007
# 71            2            ER   2024     1       48       8         1007
# 72            2            ER   2024     1       48       8         1007
# 73            2            ER   2024     1       48       8         1007
# 74            2            ER   2024     1       48       8         1007
# 75            2            ER   2024     1       48       8         1007
#
#     nb_abstentions  nb_votants  nb_emargements  nb_blanc  nb_nuls  \
# 38             507         500             500         2        2
# 39             507         500             500         2        2
# 40             507         500             500         2        2
# 41             507         500             500         2        2
# 42             507         500             500         2        2
# 43             507         500             500         2        2
# 44             507         500             500         2        2
# 45             507         500             500         2        2
# 46             507         500             500         2        2
# 47             507         500             500         2        2
# 48             507         500             500         2        2
# 49             507         500             500         2        2
# 50             507         500             500         2        2
# 51             507         500             500         2        2
# 52             507         500             500         2        2
# 53             507         500             500         2        2
# 54             507         500             500         2        2
# 55             507         500             500         2        2
# 56             507         500             500         2        2
# 57             507         500             500         2        2
# 58             507         500             500         2        2
# 59             507         500             500         2        2
# 60             507         500             500         2        2
# 61             507         500             500         2        2
# 62             507         500             500         2        2
# 63             507         500             500         2        2
# 64             507         500             500         2        2
# 65             507         500             500         2        2
# 66             507         500             500         2        2
# 67             507         500             500         2        2
# 68             507         500             500         2        2
# 69             507         500             500         2        2
# 70             507         500             500         2        2
# 71             507         500             500         2        2
# 72             507         500             500         2        2
# 73             507         500             500         2        2
# 74             507         500             500         2        2
# 75             507         500             500         2        2
#
#          candidat  nb_voix
# 38   voix_liste_1        2
# 39   voix_liste_2        2
# 40   voix_liste_3        3
# 41   voix_liste_4        5
# 42   voix_liste_5        6
# 43   voix_liste_6       10
# 44   voix_liste_7        2
# 45   voix_liste_8       10
# 46   voix_liste_9       20
# 47  voix_liste_10        2
# 48  voix_liste_11       50
# 49  voix_liste_12        1
# 50  voix_liste_13        5
# 51  voix_liste_14        9
# 52  voix_liste_15        1
# 53  voix_liste_16        2
# 54  voix_liste_17        9
# 55  voix_liste_18        7
# 56  voix_liste_19       50
# 57  voix_liste_20        2
# 58  voix_liste_21        1
# 59  voix_liste_22        2
# 60  voix_liste_23        7
# 61  voix_liste_24        2
# 62  voix_liste_25        1
# 63  voix_liste_26        1
# 64  voix_liste_27      100
# 65  voix_liste_28        1
# 66  voix_liste_29        5
# 67  voix_liste_30       50
# 68  voix_liste_31        1
# 69  voix_liste_32        2
# 70  voix_liste_33      100
# 71  voix_liste_34        1
# 72  voix_liste_35       20
# 73  voix_liste_36        1
# 74  voix_liste_37        2
# 75  voix_liste_38        1
